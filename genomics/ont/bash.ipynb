# %% [markdown]
# # Oxford Nanopore (ONT) genomics analysis
#
# This technology performs "long-read" sequencing, allowing analysis of regions hard to read with older methods.

# %%
## First, load all the necessary packages for this analysis
    # the attached env.yml holds the commands to activate a conda environment
# !conda env create -f env.yml
# !conda activate ont_variant_calling
# Out:
# Retrieving notices: done
# Channels:
#  - bioconda
#  - conda-forge
#  - defaults
# Platform: linux-64
# ...
# Solving environment: failed
#
# LibMambaUnsatisfiableError: Encountered problems while solving:
#   - unsupported request
#   - package deepvariant-1.5.0-py36hf3e76ba_0 requires python >=3.6,<3.7.0a0, but none of the providers can be installed
#   - package pycoqc-2.5.2-py_0 requires pandas 0.25.1.*, but none of the providers can be installed
#
# Could not solve for environment specs
# The following packages are incompatible
# ├─ biopython =1.83 * is installable with the potential options
# │  ├─ biopython 1.83 would require
# │  │  ├─ pypy3.9 >=7.3.13 *, which requires
# │  │  │  └─ python =3.9 *_73_pypy, which can be installed;
# │  │  └─ python_abi ==3.9 *_pypy39_pp73 with the potential options
# │  │     ├─ python_abi 3.9, which can be installed;
# │  │     └─ python_abi 3.9 would require
# │  │        └─ python =3.9 *_73_pypy, which can be installed;
# ...

# %%
# !wget -r -nH --cut-dirs=3 -np -R "index.html*" https://ont-open-data.s3.amazonaws.com/gm24385_2023-05-11/F2/
# Out:
# --2025-04-24 13:13:00--  https://ont-open-data.s3.amazonaws.com/gm24385_2023-05-11/F2/
# Resolving ont-open-data.s3.amazonaws.com (ont-open-data.s3.amazonaws.com)... 52.218.101.2, 52.218.110.122, 3.5.70.62, ...
# Connecting to ont-open-data.s3.amazonaws.com (ont-open-data.s3.amazonaws.com)|52.218.101.2|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-04-24 13:13:00 ERROR 404: Not Found.

# %%
# !code .
